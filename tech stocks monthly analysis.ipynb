# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv("https://lukestein-classes.github.io/fdap/data/monthly-tech.csv", na_values=["C"], parse_dates =["date"])
df
# Out:
# C:\Users\trupt\AppData\Local\Temp\ipykernel_60788\1242484642.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df = pd.read_csv("https://lukestein-classes.github.io/fdap/data/monthly-tech.csv", na_values=["C"], parse_dates =["date"])
#      PERMNO       date TICKER         PRC       RET  SPREAD    vwretd  \
# 0     10107 2007-01-31   MSFT    30.86000  0.033490     NaN  0.019397
# 1     10107 2007-02-28   MSFT    28.17000 -0.083927     NaN -0.013988
# 2     10107 2007-03-30   MSFT    27.87000 -0.010650     NaN  0.012950
# 3     10107 2007-04-30   MSFT    29.94000  0.074273     NaN  0.039815
# 4     10107 2007-05-31   MSFT    30.69010  0.028393     NaN  0.038932
# ..      ...        ...    ...         ...       ...     ...       ...
# 863   90319 2019-08-30  GOOGL  1190.53003 -0.022714     NaN -0.020271
# ...

# %%
df.RET.dropna()
# Out:
# 0      0.033490
# 1     -0.083927
# 2     -0.010650
# 3      0.074273
# 4      0.028393
#          ...
# 863   -0.022714
# 864    0.025711
# 865    0.030840
# 866    0.035979
# 867    0.027069
# Name: RET, Length: 861, dtype: float64

# %%
df["RET"].min()
# Out:
# -0.75

# %%
df["RET"].idxmin()
# Out:
# 710

# %%
df.loc[710]
# Out:
# PERMNO                  86298
# date      2007-05-31 00:00:00
# TICKER                   TWTR
# PRC                      0.41
# RET                     -0.75
# SPREAD                    NaN
# vwretd               0.038932
# vwretx               0.036643
# Name: 710, dtype: object

# %%
sns.displot(data=df, x = "RET", aspect=2)
# Out:
# c:\Users\trupt\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
df["RET"].mean()
# Out:
# 0.014594073170731706

# %%
df.groupby("TICKER")["RET"].std()
# Out:
# TICKER
# AAPL     0.089187
# FB       0.104273
# GOOG     0.077708
# GOOGL    0.056875
# IBM      0.058063
# MSFT     0.067236
# TWTR     0.175076
# Name: RET, dtype: float64

# %%
df.groupby("TICKER")["RET"].mean() / df.groupby("TICKER")["RET"].std()
# Out:
# TICKER
# AAPL     0.287211
# FB       0.254874
# GOOG     0.189602
# GOOGL    0.251372
# IBM      0.103447
# MSFT     0.220886
# TWTR    -0.027313
# Name: RET, dtype: float64

# %%
sns.relplot(data = df, x = "date", y = "RET", hue = "TICKER")
# Out:
# c:\Users\trupt\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.relplot(data = df, x = "date", y = "RET", hue = "TICKER", col = "TICKER", col_wrap=3)
# Out:
# c:\Users\trupt\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
